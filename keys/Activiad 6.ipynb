# %%
import requests
import pandas as pd
import numpy as np
from keys import *

city = "Naucalpan"
country = "MX"
response = requests.get(
    f"http://api.openweathermap.org/data/2.5/forecast?q={city},{country}&appid={OWM_key}"
)
data = response.json()
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1758931200,
#    'main': {'temp': 292.78,
#     'feels_like': 292.5,
#     'temp_min': 289.97,
#     'temp_max': 292.78,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 753,
#     'humidity': 65,
#     'temp_kf': 2.81},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.24, 'deg': 322, 'gust': 3.61},
#    'visibility': 9830,
#    'pop': 1,
#    'rain': {'3h': 3.38},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-27 00:00:00'},
#   {'dt': 1758942000,
#    'main': {'temp': 291.16,
#     'feels_like': 290.84,
#     'temp_min': 289.64,
#     'temp_max': 291.16,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 754,
#     'humidity': 70,
#     'temp_kf': 1.52},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 1.19, 'deg': 290, 'gust': 1.22},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-27 03:00:00'},
#   {'dt': 1758952800,
#    'main': {'temp': 290,
#     'feels_like': 289.72,
#     'temp_min': 290,
#     'temp_max': 290,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.21, 'deg': 269, 'gust': 1.24},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.35},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-27 06:00:00'},
#   {'dt': 1758963600,
#    'main': {'temp': 288.17,
#     'feels_like': 287.87,
#     'temp_min': 288.17,
#     'temp_max': 288.17,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 753,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 1.26, 'deg': 268, 'gust': 1.43},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 0.59},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-27 09:00:00'},
#   {'dt': 1758974400,
#    'main': {'temp': 287.97,
#     'feels_like': 287.67,
#     'temp_min': 287.97,
#     'temp_max': 287.97,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 753,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 1.12, 'deg': 250, 'gust': 1.04},
#    'visibility': 10000,
#    'pop': 0.31,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-27 12:00:00'},
#   {'dt': 1758985200,
#    'main': {'temp': 290.5,
#     'feels_like': 290.17,
#     'temp_min': 290.5,
#     'temp_max': 290.5,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 755,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 1.41, 'deg': 50, 'gust': 1.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-27 15:00:00'},
#   {'dt': 1758996000,
#    'main': {'temp': 295.47,
#     'feels_like': 294.91,
#     'temp_min': 295.47,
#     'temp_max': 295.47,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 754,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.96, 'deg': 53, 'gust': 2.4},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-27 18:00:00'},
#   {'dt': 1759006800,
#    'main': {'temp': 298.11,
#     'feels_like': 297.5,
#     'temp_min': 298.11,
#     'temp_max': 298.11,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 751,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 3.42, 'deg': 28, 'gust': 2.73},
#    'visibility': 10000,
#    'pop': 0.24,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-27 21:00:00'},
#   {'dt': 1759017600,
#    'main': {'temp': 294.34,
#     'feels_like': 293.77,
#     'temp_min': 294.34,
#     'temp_max': 294.34,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 752,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 4.13, 'deg': 23, 'gust': 4.77},
#    'visibility': 10000,
#    'pop': 0.27,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-28 00:00:00'},
#   {'dt': 1759028400,
#    'main': {'temp': 292.1,
#     'feels_like': 291.77,
#     'temp_min': 292.1,
#     'temp_max': 292.1,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 753,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 2.24, 'deg': 7, 'gust': 3.39},
#    'visibility': 10000,
#    'pop': 0.33,
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-28 03:00:00'},
#   {'dt': 1759039200,
#    'main': {'temp': 290.3,
#     'feels_like': 290.06,
#     'temp_min': 290.3,
#     'temp_max': 290.3,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 1.44, 'deg': 353, 'gust': 1.87},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-28 06:00:00'},
#   {'dt': 1759050000,
#    'main': {'temp': 288.95,
#     'feels_like': 288.73,
#     'temp_min': 288.95,
#     'temp_max': 288.95,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 753,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 1.02, 'deg': 19, 'gust': 1.27},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-28 09:00:00'},
#   {'dt': 1759060800,
#    'main': {'temp': 288,
#     'feels_like': 287.81,
#     'temp_min': 288,
#     'temp_max': 288,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 38},
#    'wind': {'speed': 1.02, 'deg': 36, 'gust': 0.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-28 12:00:00'},
#   {'dt': 1759071600,
#    'main': {'temp': 290.25,
#     'feels_like': 289.95,
#     'temp_min': 290.25,
#     'temp_max': 290.25,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 755,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.15, 'deg': 69, 'gust': 0.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-28 15:00:00'},
#   {'dt': 1759082400,
#    'main': {'temp': 295.4,
#     'feels_like': 294.93,
#     'temp_min': 295.4,
#     'temp_max': 295.4,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 754,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 2.53, 'deg': 71, 'gust': 1.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-28 18:00:00'},
#   {'dt': 1759093200,
#    'main': {'temp': 297.82,
#     'feels_like': 297.2,
#     'temp_min': 297.82,
#     'temp_max': 297.82,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 752,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 3.79, 'deg': 46, 'gust': 2.55},
#    'visibility': 10000,
#    'pop': 0.16,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-28 21:00:00'},
#   {'dt': 1759104000,
#    'main': {'temp': 294.37,
#     'feels_like': 293.88,
#     'temp_min': 294.37,
#     'temp_max': 294.37,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 752,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 4.68, 'deg': 43, 'gust': 4.93},
#    'visibility': 10000,
#    'pop': 0.36,
#    'rain': {'3h': 0.21},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-29 00:00:00'},
#   {'dt': 1759114800,
#    'main': {'temp': 291.98,
#     'feels_like': 291.67,
#     'temp_min': 291.98,
#     'temp_max': 291.98,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 2.33, 'deg': 5, 'gust': 3.05},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-29 03:00:00'},
#   {'dt': 1759125600,
#    'main': {'temp': 289.53,
#     'feels_like': 289.39,
#     'temp_min': 289.53,
#     'temp_max': 289.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.83, 'deg': 23, 'gust': 1.94},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-29 06:00:00'},
#   {'dt': 1759136400,
#    'main': {'temp': 288.74,
#     'feels_like': 288.57,
#     'temp_min': 288.74,
#     'temp_max': 288.74,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.76, 'deg': 18, 'gust': 1.82},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.94},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-29 09:00:00'},
#   {'dt': 1759147200,
#    'main': {'temp': 288.28,
#     'feels_like': 288.09,
#     'temp_min': 288.28,
#     'temp_max': 288.28,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 754,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 1.42, 'deg': 53, 'gust': 1.29},
#    'visibility': 10000,
#    'pop': 0.91,
#    'rain': {'3h': 0.37},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-29 12:00:00'},
#   {'dt': 1759158000,
#    'main': {'temp': 289.97,
#     'feels_like': 289.64,
#     'temp_min': 289.97,
#     'temp_max': 289.97,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 755,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.21, 'deg': 87, 'gust': 0.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-29 15:00:00'},
#   {'dt': 1759168800,
#    'main': {'temp': 295.05,
#     'feels_like': 294.63,
#     'temp_min': 295.05,
#     'temp_max': 295.05,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 1.82, 'deg': 88, 'gust': 1.11},
#    'visibility': 10000,
#    'pop': 0.46,
#    'rain': {'3h': 0.3},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-29 18:00:00'},
#   {'dt': 1759179600,
#    'main': {'temp': 297.47,
#     'feels_like': 297,
#     'temp_min': 297.47,
#     'temp_max': 297.47,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 752,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 2.64, 'deg': 103, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0.73,
#    'rain': {'3h': 0.57},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-29 21:00:00'},
#   {'dt': 1759190400,
#    'main': {'temp': 293.64,
#     'feels_like': 293.31,
#     'temp_min': 293.64,
#     'temp_max': 293.64,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 753,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.82, 'deg': 22, 'gust': 3.72},
#    'visibility': 8777,
#    'pop': 0.83,
#    'rain': {'3h': 1.32},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-30 00:00:00'},
#   {'dt': 1759201200,
#    'main': {'temp': 291.17,
#     'feels_like': 290.96,
#     'temp_min': 291.17,
#     'temp_max': 291.17,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.89, 'deg': 23, 'gust': 2.83},
#    'visibility': 3974,
#    'pop': 1,
#    'rain': {'3h': 2.88},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-30 03:00:00'},
#   {'dt': 1759212000,
#    'main': {'temp': 289.24,
#     'feels_like': 289.07,
#     'temp_min': 289.24,
#     'temp_max': 289.24,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 755,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1, 'deg': 347, 'gust': 1.11},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-30 06:00:00'},
#   {'dt': 1759222800,
#    'main': {'temp': 288.85,
#     'feels_like': 288.72,
#     'temp_min': 288.85,
#     'temp_max': 288.85,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.09, 'deg': 20, 'gust': 1.14},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.37},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-30 09:00:00'},
#   {'dt': 1759233600,
#    'main': {'temp': 288.6,
#     'feels_like': 288.52,
#     'temp_min': 288.6,
#     'temp_max': 288.6,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 754,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.18, 'deg': 42, 'gust': 1.33},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.77},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-09-30 12:00:00'},
#   {'dt': 1759244400,
#    'main': {'temp': 290.09,
#     'feels_like': 289.88,
#     'temp_min': 290.09,
#     'temp_max': 290.09,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 756,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.38, 'deg': 41, 'gust': 0.78},
#    'visibility': 10000,
#    'pop': 0.8,
#    'rain': {'3h': 0.54},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-30 15:00:00'},
#   {'dt': 1759255200,
#    'main': {'temp': 294.07,
#     'feels_like': 293.76,
#     'temp_min': 294.07,
#     'temp_max': 294.07,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 755,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 0.87, 'deg': 22, 'gust': 0.57},
#    'visibility': 10000,
#    'pop': 0.86,
#    'rain': {'3h': 1.1},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-30 18:00:00'},
#   {'dt': 1759266000,
#    'main': {'temp': 295.52,
#     'feels_like': 295.17,
#     'temp_min': 295.52,
#     'temp_max': 295.52,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 752,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 2.28, 'deg': 21, 'gust': 2.03},
#    'visibility': 6375,
#    'pop': 1,
#    'rain': {'3h': 1.54},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-09-30 21:00:00'},
#   {'dt': 1759276800,
#    'main': {'temp': 291.94,
#     'feels_like': 291.73,
#     'temp_min': 291.94,
#     'temp_max': 291.94,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 753,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 2.06, 'deg': 22, 'gust': 2.67},
#    'visibility': 4435,
#    'pop': 1,
#    'rain': {'3h': 4.6},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-10-01 00:00:00'},
#   {'dt': 1759287600,
#    'main': {'temp': 290.54,
#     'feels_like': 290.37,
#     'temp_min': 290.54,
#     'temp_max': 290.54,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.98, 'deg': 326, 'gust': 1.41},
#    'visibility': 9907,
#    'pop': 1,
#    'rain': {'3h': 3.46},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-10-01 03:00:00'},
#   {'dt': 1759298400,
#    'main': {'temp': 289.57,
#     'feels_like': 289.46,
#     'temp_min': 289.57,
#     'temp_max': 289.57,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.33, 'deg': 23, 'gust': 1.89},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-10-01 06:00:00'},
#   {'dt': 1759309200,
#    'main': {'temp': 288.52,
#     'feels_like': 288.44,
#     'temp_min': 288.52,
#     'temp_max': 288.52,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 754,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.04, 'deg': 1, 'gust': 2.47},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.94},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-10-01 09:00:00'},
#   {'dt': 1759320000,
#    'main': {'temp': 288.05,
#     'feels_like': 288,
#     'temp_min': 288.05,
#     'temp_max': 288.05,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 754,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.05, 'deg': 36, 'gust': 2.43},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.02},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-10-01 12:00:00'},
#   {'dt': 1759330800,
#    'main': {'temp': 288.97,
#     'feels_like': 288.83,
#     'temp_min': 288.97,
#     'temp_max': 288.97,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 755,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.53, 'deg': 63, 'gust': 1.23},
#    'visibility': 10000,
#    'pop': 0.6,
#    'rain': {'3h': 0.45},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-10-01 15:00:00'},
#   {'dt': 1759341600,
#    'main': {'temp': 293.16,
#     'feels_like': 292.84,
#     'temp_min': 293.16,
#     'temp_max': 293.16,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 754,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 2.14, 'deg': 45, 'gust': 1.68},
#    'visibility': 10000,
#    'pop': 0.57,
#    'rain': {'3h': 0.3},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-10-01 18:00:00'},
#   {'dt': 1759352400,
#    'main': {'temp': 294.12,
#     'feels_like': 293.68,
#     'temp_min': 294.12,
#     'temp_max': 294.12,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 752,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.06, 'deg': 16, 'gust': 2.26},
#    'visibility': 10000,
#    'pop': 0.83,
#    'rain': {'3h': 0.63},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-10-01 21:00:00'}],
#  'city': {'id': 3522790,
#   'name': 'Naucalpan',
#   'coord': {'lat': 19.4785, 'lon': -99.2396},
#   'country': 'MX',
#   'population': 846185,
#   'timezone': -21600,
#   'sunrise': 1758889598,
#   'sunset': 1758932980}}

# %%
data = response.json()

# %%
# Extract forecast list
forecast_list = data.get('list', [])

# %%
# Prepare lists for DataFrame columns
times = []
temperatures = []
humidities = []
weather_statuses = []
wind_speeds = []
rain_volumes = []
snow_volumes = []

for entry in forecast_list:
    times.append(entry.get('dt_txt', np.nan))
    temperatures.append(entry.get('main', {}).get('temp', np.nan))
    humidities.append(entry.get('main', {}).get('humidity', np.nan))
    weather_statuses.append(entry.get('weather', [{}])[0].get('main', np.nan))
    wind_speeds.append(entry.get('wind', {}).get('speed', np.nan))
    rain_volumes.append(entry.get('rain', {}).get('3h', np.nan))
    snow_volumes.append(entry.get('snow', {}).get('3h', np.nan))

# %%
# Create DataFrame
df = pd.DataFrame({
    'time': times,
    'temperature': temperatures,
    'humidity': humidities,
    'weather_status': weather_statuses,
    'wind_speed': wind_speeds,
    'rain_volume_3h': rain_volumes,
    'snow_volume_3h': snow_volumes
})

print(df.head())
# Out:
#                   time  temperature  humidity weather_status  wind_speed  \
# 0  2025-09-27 00:00:00       292.78        65           Rain        2.24
# 1  2025-09-27 03:00:00       291.16        70           Rain        1.19
# 2  2025-09-27 06:00:00       290.00        76           Rain        1.21
# 3  2025-09-27 09:00:00       288.17        82           Rain        1.26
# 4  2025-09-27 12:00:00       287.97        83         Clouds        1.12
#
#    rain_volume_3h  snow_volume_3h
# 0            3.38             NaN
# 1            2.19             NaN
# 2            1.35             NaN
# 3            0.59             NaN
# 4             NaN             NaN
